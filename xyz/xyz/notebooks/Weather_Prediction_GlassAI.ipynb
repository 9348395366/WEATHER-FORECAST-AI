# %% [markdown]
# # Glass Weather AI -- Jupyter Walkthrough
#
# This notebook prepares a large weather dataset, trains a forecasting model, and saves it for the Streamlit UI.

# %%
from pathlib import Path

import pandas as pd

from src.data import load_or_generate_dataset
from src.modeling import train_model, save_model

# %%
DATA_PATH = Path("../data/historical_weather.csv")
MODEL_PATH = Path("../models/temperature_model.pkl")

df, source = load_or_generate_dataset(DATA_PATH)
df.head()

# %% [markdown]
# ## Train the model

# %%
model, metrics = train_model(df)
metrics

# %%
save_model(model, MODEL_PATH)
print('Model saved to', MODEL_PATH)

# %% [markdown]
# ## Next steps
# - Launch the UI with `streamlit run app.py`.
# - Explore the Data Lab and Agent Chat pages in the app.
